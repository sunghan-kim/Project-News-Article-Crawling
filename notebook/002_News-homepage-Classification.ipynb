# %% [markdown]
# # 2. 뉴스 홈페이지 분류
#
# - 신문사 홈페이지별로 기사 내용이 서로 다른 형태의 html로 구성되어 있을 것이다.
# - rawdata에 있는 기사 링크에 있는 홈페이지 목록을 정리한다.
# - 이를 바탕으로 각 홈페이지별 크롤링 방법을 정의할 예정이다.

# %% [markdown]
# <br>
#
# ## 2.1 데이터프레임 읽기
#
# - 이전에 생성한 기사 링크가 포함된 데이터프레임을 읽어온다.

# %%
import pandas as pd

df_origin = pd.read_csv('news_info.csv')
df_origin.head()
# Out:
#    NewsDate                              NewsTitle  \
# 0  20200129  농협은행, 전 영업점에 방역 작업...'우한 폐렴' 확산 방지 총력
# 1  20200129                  윤종원 제26대 IBK기업은행장 취임식
# 2  20200131               신한銀의 파격실험 영업점, 돈 안벌어도 OK
# 3  20200203              국민은행 디지털 전환 첨병된 '인사이트 지점'
# 4  20200203     신한은행 지점 암행평가 270곳 펀드 판매정지…질적 도약 기회
#
#                                                 Path  \
# 0  ..\rawdata\기업별 관련기사\은행\NH농협은행\20200129 농협은행, 전...
# 1  ..\rawdata\기업별 관련기사\은행\IBK기업은행\20200129 윤종원 제2...
# 2  ..\rawdata\기업별 관련기사\은행\신한은행\20200131 신한銀의 파격실험...
# 3  ..\rawdata\기업별 관련기사\은행\KB국민은행\20200203 국민은행 디지...
# 4  ..\rawdata\기업별 관련기사\은행\신한은행\20200203 신한은행 지점 암...
#
#                                                  URL
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...
# 2  https://www.hankyung.com/economy/article/20200...
# 3  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4  http://news.mtn.co.kr/newscenter/news_viewer.m...

# %%
print(len(df_origin))
# Out:
# 343

# %% [markdown]
# <br>
#
# ## 2.2 기사 링크 중복 확인
#
# - rawdata에 같은 기사가 서로 다른 폴더에 있는 경우가 있다.
# - 그렇기 때문에 파일 경로(`Path`) 정보를 제외한 나머지 정보가 중복된 데이터들이 존재한다.
# - 이 중복된 데이터들을 확인해보자.

# %%
df = df_origin.drop(columns=["Path"], axis=1)
df.head()
# Out:
#    NewsDate                              NewsTitle  \
# 0  20200129  농협은행, 전 영업점에 방역 작업...'우한 폐렴' 확산 방지 총력
# 1  20200129                  윤종원 제26대 IBK기업은행장 취임식
# 2  20200131               신한銀의 파격실험 영업점, 돈 안벌어도 OK
# 3  20200203              국민은행 디지털 전환 첨병된 '인사이트 지점'
# 4  20200203     신한은행 지점 암행평가 270곳 펀드 판매정지…질적 도약 기회
#
#                                                  URL
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...
# 2  https://www.hankyung.com/economy/article/20200...
# 3  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4  http://news.mtn.co.kr/newscenter/news_viewer.m...

# %%
# 중복 확인
df[df.duplicated()].head(10)
# Out:
#     NewsDate                        NewsTitle  \
# 27  20200220          사고 안 나면 보험료 돌려주는 보험 나온다
# 28  20200220          사고 안 나면 보험료 돌려주는 보험 나온다
# 31  20200221  DLF·라임에 데인 은행들, AI로 '불완전판매' 잡는다
# 32  20200221  DLF·라임에 데인 은행들, AI로 '불완전판매' 잡는다
# 33  20200221  DLF·라임에 데인 은행들, AI로 '불완전판매' 잡는다
# 35  20200221           굿바이 보험아줌마…로봇 설계사 시대 온다
# 36  20200221           굿바이 보험아줌마…로봇 설계사 시대 온다
# 37  20200221           굿바이 보험아줌마…로봇 설계사 시대 온다
# 38  20200221           굿바이 보험아줌마…로봇 설계사 시대 온다
# 39  20200221           굿바이 보험아줌마…로봇 설계사 시대 온다
#
#                                                   URL
# 27  https://news.naver.com/main/read.nhn?mode=LS2D...
# 28  https://news.naver.com/main/read.nhn?mode=LS2D...
# 31  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 32  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 33  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 35  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 36  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 37  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 38  https://m.news.naver.com/read.nhn?mode=LSD&sid...
# 39  https://m.news.naver.com/read.nhn?mode=LSD&sid...

# %%
# 중복 제거
df = df.drop_duplicates()
df.head(10)
# Out:
#    NewsDate                                   NewsTitle  \
# 0  20200129       농협은행, 전 영업점에 방역 작업...'우한 폐렴' 확산 방지 총력
# 1  20200129                       윤종원 제26대 IBK기업은행장 취임식
# 2  20200131                    신한銀의 파격실험 영업점, 돈 안벌어도 OK
# 3  20200203                   국민은행 디지털 전환 첨병된 '인사이트 지점'
# 4  20200203          신한은행 지점 암행평가 270곳 펀드 판매정지…질적 도약 기회
# 5  20200203                        신한은행, 순이익 목표 10% 낮췄다
# 6  20200204           '종합금융그룹' 강조한 윤종원 기업은행장 지주 전환 도전할까
# 7  20200204          보험업계는 '제로성장'이라는데, 은행들은 왜 보험사를 사들일까
# 8  20200204  우리은행, 금감원 키코 분쟁조정안 전격 수용... 다른 은행들도 배상 나설까
# 9  20200204                 하나금융, 역대 최대 순이익…'은행 쏠림'은 고민
#
#                                                  URL
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...
# 2  https://www.hankyung.com/economy/article/20200...
# 3  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4  http://news.mtn.co.kr/newscenter/news_viewer.m...
# 5  https://www.hankyung.com/economy/article/20200...
# 6    https://n.news.naver.com/article/421/0004439723
# 7    https://n.news.naver.com/article/025/0002972080
# 8  https://www.hankookilbo.com/News/Read/20200203...
# 9  https://news.naver.com/main/read.nhn?mode=LS2D...

# %% [markdown]
# <br>
#
# ## 2.3 뉴스 홈페이지 주소 획득
